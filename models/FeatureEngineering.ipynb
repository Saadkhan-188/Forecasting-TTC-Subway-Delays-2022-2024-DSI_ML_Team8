# %%
# Load the dataset

import pandas as pd
import os

df = pd.read_excel("./ttc-subway-delay-data-2024.xlsx")   # Load excel file
print(df.head())     # Display the first few rows
# Out:
#         Date   Time     Day             Station   Code  Min Delay  Min Gap  \
# 0 2024-01-01  02:00  Monday    SHEPPARD STATION    MUI          0        0
# 1 2024-01-01  02:00  Monday      DUNDAS STATION   MUIS          0        0
# 2 2024-01-01  02:08  Monday      DUNDAS STATION  MUPAA          4       10
# 3 2024-01-01  02:13  Monday  KENNEDY BD STATION  PUTDN         10       16
# 4 2024-01-01  02:22  Monday       BLOOR STATION  MUPAA          4       10
#
#   Bound Line  Vehicle
# 0     N   YU     5491
# 1     N   YU        0
# 2     N   YU     6051
# 3     E   BD     5284
# 4     N   YU     5986

# %%
# Drop the 'Vehicle' column
df.drop(columns='Vehicle', inplace=True)
df.drop('Bound', axis=1, inplace=True)
df.columns
# Out:
# Index(['Date', 'Time', 'Day', 'Station', 'Code', 'Min Delay', 'Min Gap',
#        'Line'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26467 entries, 0 to 26466
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       26467 non-null  datetime64[ns]
#  1   Time       26467 non-null  object
#  2   Day        26467 non-null  object
#  3   Station    26467 non-null  object
#  4   Code       26467 non-null  object
#  5   Min Delay  26467 non-null  int64
#  6   Min Gap    26467 non-null  int64
#  7   Line       26423 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 1.6+ MB
# None

# %% [markdown]
# Cleaning 'Line' column data

# %%
df['Line'].unique()
# Out:
# array(['YU', 'BD', 'YUS', 'YU/BD', 'SHP', nan, 'BLOOR DANFORTH',
#        'YU / BD', 'YU/ BD', 'SRT', 'YUS/BD', 'SHEP', 'LINE 1',
#        'TRACK LEVEL ACTIVITY', 'YU & BD', '109 RANEE',
#        'ONGE-UNIVERSITY AND BL', 'YU/BD/SHP', 'BD/ YUS', 'BD/ YU',
#        'BD/YU', 'BD / YU', '20 CLIFFSIDE'], dtype=object)

# %%
df[df['Line'].isna()]
# Out:
#             Date   Time        Day                 Station   Code  Min Delay  \
# 2257  2024-01-31  01:41  Wednesday         SPADINA STATION   MUIS          0
# 2498  2024-02-04  00:08     Sunday     SPADINA YUS STATION   MUIS          0
# 3413  2024-02-16  22:01     Friday           GUNN BUILDING   PUMO          0
# 3687  2024-02-20  22:13    Tuesday           QUEEN STATION    SUO          0
# 7095  2024-04-07  01:11     Sunday        UNKNOWN LOCATION    MUO          0
# 7253  2024-04-09  22:01    Tuesday          LESLIE STATION    MUO          0
# 7438  2024-04-11  01:06   Thursday     SPADINA YUS STATION  MUIRS          0
# 7447  2024-04-12  03:45     Friday       HILLCREST COMPLEX    SUG          0
# 9567  2024-05-09  18:05   Thursday       VARIOUS LOCATIONS    MUO          0
# 10357 2024-05-20  04:39     Monday          HILLCREST GATE    SUO          0
# 11079 2024-05-30  10:21   Thursday     SUBWAY OPS BUILDING    MUO          0
# 11606 2024-06-06  23:07   Thursday      SPADINA BD STATION  MUIRS          0
# 12472 2024-06-20  22:00   Thursday  YONGE-UNIVERSITY AND B    MUO          0
# 13186 2024-07-01  22:08     Monday            MCCOWAN YARD    SUG          0
# 13601 2024-07-08  01:58     Monday         SPADINA STATION   MUIS          0
# 13743 2024-07-10  21:43  Wednesday            MCCOWAN YARD    SUG          0
# 13749 2024-07-10  23:15  Wednesday         SPADINA STATION    SUO          0
# 13825 2024-07-11  23:01   Thursday            MCCOWAN YARD    SUG          0
# 13976 2024-07-14  12:09     Sunday      DAVISVILLE OFFICES    SUO          0
# 14128 2024-07-16  10:47    Tuesday         KIPLING & UNION    MUO          0
# 14147 2024-07-16  12:53    Tuesday    QUEEN'S QUAY STATION  PUMEL          0
# 14479 2024-07-21  23:21     Sunday        YONGE BD STATION  PUMEL          0
# 15005 2024-07-29  12:04     Monday  GREENWOOD SHOPS - 41 T   MUIE          0
# 15046 2024-07-30  04:21    Tuesday   ST CLAIR WEST STATION    MUO          0
# 16404 2024-08-16  22:00     Friday  YONGE-UNIVERSITY AND B    MUO          0
# 17050 2024-08-25  23:45     Sunday  EGLINTON - SCARBOROUGH    MUO          0
# 19044 2024-09-21  01:32   Saturday          GREENWOOD YARD    SUO          0
# 19689 2024-09-30  22:59     Monday  VICTORIA PARK TO KENNE    MUO          0
# 20438 2024-10-10  09:17   Thursday       GREENWOOD COMPLEX    MUO          0
# 22385 2024-11-06  22:52  Wednesday            MCCOWAN YARD    SUO          0
# 22951 2024-11-14  18:59   Thursday  HILLCREST COMPLEX - IN   MUIE          0
# 23416 2024-11-21  07:33   Thursday         INGLIS BUILDING  PUMEL          0
# 23576 2024-11-23  03:04   Saturday  HILLCREST POWER CONTRO    MUO          0
# 24253 2024-12-02  22:40     Monday   SUBWAY CLOSURE: EARLY    MUO          0
# 24338 2024-12-03  23:00    Tuesday   SUBWAY CLOSURE: EARLY    MUO          0
# 24430 2024-12-04  23:00  Wednesday   SUBWAY CLOSURE: EARLY    MUO          0
# 24433 2024-12-04  00:37  Wednesday         COLLEGE STATION   SUDP          0
# 24808 2024-12-09  23:00     Monday  EARLY ACCESS CLOSURE S    MUO          0
# 24901 2024-12-10  23:50    Tuesday  GREENWOOD TRACK/STRUCT   MUWR          0
# 24979 2024-12-11  23:00  Wednesday  EARLY ACCESS CLOSURE S    MUO          0
# 25430 2024-12-18  13:02  Wednesday           GUNN BUILDING   PUMO          0
# 25657 2024-12-21  07:54   Saturday            391 ALLIANCE    SUO          0
# 26077 2024-12-27  12:04     Friday       DUNCAN SUBSTATION   MUIE          0
# 26115 2024-12-27  21:21     Friday     MAIN STREET STATION   EUSC          0
#
#        Min Gap Line
# 2257         0  NaN
# 2498         0  NaN
# 3413         0  NaN
# 3687         0  NaN
# 7095         0  NaN
# 7253         0  NaN
# 7438         0  NaN
# 7447         0  NaN
# 9567         0  NaN
# 10357        0  NaN
# 11079        0  NaN
# 11606        0  NaN
# 12472        0  NaN
# 13186        0  NaN
# 13601        0  NaN
# 13743        0  NaN
# 13749        0  NaN
# 13825        0  NaN
# 13976        0  NaN
# 14128        0  NaN
# 14147        0  NaN
# 14479        0  NaN
# 15005        0  NaN
# 15046        0  NaN
# 16404        0  NaN
# 17050        0  NaN
# 19044        0  NaN
# 19689        0  NaN
# 20438        0  NaN
# 22385        0  NaN
# 22951        0  NaN
# 23416        0  NaN
# 23576        0  NaN
# 24253        0  NaN
# 24338        0  NaN
# 24430        0  NaN
# 24433        0  NaN
# 24808        0  NaN
# 24901        0  NaN
# 24979        0  NaN
# 25430        0  NaN
# 25657        0  NaN
# 26077        0  NaN
# 26115        0  NaN

# %%
stations_to_drop = [
    "UNKNOWN LOCATION", "VARIOUS LOCATIONS", "SUBWAY OPS BUILDING",
    "HILLCREST GATE", "GREENWOOD YARD", "GREENWOOD SHOPS - 41 T",
    "HILLCREST POWER CONTRO", "HILLCREST COMPLEX - IN", "DUNCAN SUBSTATION",
    "SUBWAY CLOSURE: EARLY", "EARLY ACCESS CLOSURE S", "INGLIS BUILDING",
    "391 ALLIANCE", "GUNN BUILDING"
]

# Drop those rows
df = df[~df['Station'].isin(stations_to_drop)]
df[df['Line'].isna()]
df[df['Line'].isna()]['Station'].unique()
# Out:
# array(['SPADINA STATION', 'SPADINA YUS STATION', 'QUEEN STATION',
#        'LESLIE STATION', 'HILLCREST COMPLEX', 'SPADINA BD STATION',
#        'YONGE-UNIVERSITY AND B', 'MCCOWAN YARD', 'DAVISVILLE OFFICES',
#        'KIPLING & UNION', "QUEEN'S QUAY STATION", 'YONGE BD STATION',
#        'ST CLAIR WEST STATION', 'EGLINTON - SCARBOROUGH',
#        'VICTORIA PARK TO KENNE', 'GREENWOOD COMPLEX', 'COLLEGE STATION',
#        'GREENWOOD TRACK/STRUCT', 'MAIN STREET STATION'], dtype=object)

# %%
# Imputing Null Values
# Step 1: Create mapping from known (non-null) Line entries

station_line_map = (
    df[~df['Line'].isna()]
    .groupby('Station')['Line']
    .agg(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)  # most frequent line
    .to_dict()
)

# Step 2: Apply mapping only to rows where Line is null
df['Line'] = df.apply(
    lambda row: station_line_map[row['Station']] if pd.isna(row['Line']) and row['Station'] in station_line_map else row['Line'],
    axis=1
)

# %%
df[df['Line'].isna()]
# Out:
#             Date   Time      Day                 Station   Code  Min Delay  \
# 7447  2024-04-12  03:45   Friday       HILLCREST COMPLEX    SUG          0
# 13976 2024-07-14  12:09   Sunday      DAVISVILLE OFFICES    SUO          0
# 14128 2024-07-16  10:47  Tuesday         KIPLING & UNION    MUO          0
# 14147 2024-07-16  12:53  Tuesday    QUEEN'S QUAY STATION  PUMEL          0
# 17050 2024-08-25  23:45   Sunday  EGLINTON - SCARBOROUGH    MUO          0
# 24901 2024-12-10  23:50  Tuesday  GREENWOOD TRACK/STRUCT   MUWR          0
#
#        Min Gap Line
# 7447         0  NaN
# 13976        0  NaN
# 14128        0  NaN
# 14147        0  NaN
# 17050        0  NaN
# 24901        0  NaN

# %%
indices_to_drop = [7447, 13976, 14128, 14147, 17050, 24901]

df.drop(index=indices_to_drop, inplace=True)

# %%
df["Line"].unique()
# Out:
# array(['YU', 'BD', 'YUS', 'YU/BD', 'SHP', 'BLOOR DANFORTH', 'YU / BD',
#        'YU/ BD', 'SRT', 'YUS/BD', 'SHEP', 'LINE 1',
#        'TRACK LEVEL ACTIVITY', 'YU & BD', '109 RANEE',
#        'ONGE-UNIVERSITY AND BL', 'YU/BD/SHP', 'BD/ YUS', 'BD/ YU',
#        'BD/YU', 'BD / YU', '20 CLIFFSIDE'], dtype=object)

# %%
# Mapping of messy line names to clean ones
line_cleaning_map = {
    'LINE 1': 'YU',
    'BLOOR DANFORTH': 'BD',
    'YU/BD': 'YU-BD',
    'YU / BD': 'YU-BD',
    'YU/ BD': 'YU-BD',
    'YU & BD': 'YU-BD',
    'BD/ YUS': 'YU-BD',
    'BD/YU': 'YU-BD',
    'BD / YU': 'YU-BD',
    'BD/ YU': 'YU-BD',
    'YUS/BD': 'YU-BD',
    'YUS': 'YU',
    'SHEP': 'SHP',
    'ONGE-UNIVERSITY AND BL': 'YU',
}

# Apply the mapping
df['Line'] = df['Line'].replace(line_cleaning_map)

# %%
# Define the line values you want to remove
lines_to_drop = ['TRACK LEVEL ACTIVITY', '109 RANEE', '20 CLIFFSIDE']

# Delete rows where 'Line' matches any of these values
df = df[~df['Line'].isin(lines_to_drop)]

# %%
df['Line'].unique()
# Out:
# array(['YU', 'BD', 'YU-BD', 'SHP', 'SRT', 'YU/BD/SHP'], dtype=object)

# %%
df['Line'].value_counts()
# Out:
# Line
# YU           14154
# BD           10903
# SHP            892
# YU-BD          385
# SRT              2
# YU/BD/SHP        1
# Name: count, dtype: int64

# %%
# Define line values to delete
lines_to_remove = ['SRT', 'YU/BD/SHP']

# Remove rows with these line values
df = df[~df['Line'].isin(lines_to_remove)]

# %% [markdown]
# Cleaning 'Station' column data

# %%
pd.set_option('display.max_rows', None)
df['Station'].value_counts()
# Out:
# Station
# BLOOR STATION             1109
# KENNEDY BD STATION         960
# FINCH STATION              896
# KIPLING STATION            894
# DUNDAS STATION             829
# EGLINTON STATION           674
# VAUGHAN MC STATION         606
# YONGE BD STATION           599
# UNION STATION              584
# COLLEGE STATION            515
# VICTORIA PARK STATION      497
# WELLESLEY STATION          456
# ST GEORGE YUS STATION      443
# WILSON STATION             442
# WARDEN STATION             439
# SPADINA BD STATION         419
# ST CLAIR STATION           406
# DAVISVILLE STATION         404
# KEELE STATION              397
# COXWELL STATION            384
# MAIN STREET STATION        381
# QUEEN STATION              371
# BROADVIEW STATION          367
# SHEPPARD STATION           364
# SHERBOURNE STATION         357
# KING STATION               352
# ST GEORGE BD STATION       350
# DUNDAS WEST STATION        348
# ST CLAIR WEST STATION      347
# YONGE-UNIVERSITY AND B     333
# BATHURST STATION           326
# SHEPPARD WEST STATION      324
# YORK MILLS STATION         316
# ISLINGTON STATION          314
# SPADINA YUS STATION        310
# LAWRENCE STATION           297
# DUFFERIN STATION           293
# SHEPPARD-YONGE STATION     285
# WOODBINE STATION           283
# OSSINGTON STATION          275
# PAPE STATION               272
# ROSEDALE STATION           266
# EGLINTON WEST STATION      255
# DONLANDS STATION           250
# DUPONT STATION             244
# GREENWOOD STATION          242
# QUEEN'S PARK STATION       241
# LAWRENCE WEST STATION      240
# DON MILLS STATION          239
# ROYAL YORK STATION         233
# CHRISTIE STATION           232
# SUMMERHILL STATION         230
# NORTH YORK CTR STATION     226
# YORKDALE STATION           224
# JANE STATION               222
# BAY STATION                219
# OLD MILL STATION           217
# OSGOODE STATION            216
# FINCH WEST STATION         201
# ST ANDREW STATION          199
# ST PATRICK STATION         196
# MUSEUM STATION             188
# CASTLE FRANK STATION       185
# RUNNYMEDE STATION          184
# HIGHWAY 407 STATION        170
# LANSDOWNE STATION          166
# HIGH PARK STATION          162
# CHESTER STATION            159
# PIONEER VILLAGE STATIO     144
# GLENCAIRN STATION          138
# LESLIE STATION             136
# DOWNSVIEW PARK STATION     123
# BAYVIEW STATION            121
# YORK UNIVERSITY STATIO     104
# BESSARION STATION           67
# DAVISVILLE YARD             50
# TORONTO TRANSIT COMMIS      45
# BLOOR DANFORTH LINE         45
# WILSON YARD                 21
# KEELE YARD                  20
# GREENWOOD CARHOUSE          19
# DAVISVILLE BUILD UP         17
# UNION STATION TO KING       14
# YONGE/UNIVERSITY AND B      14
# LINE 2 BLOOR DANFORTH       14
# LINE 1 - YONGE UNIVERS      13
# ST CLAIR STATION TO SH      11
# YONGE UNIVERSITY AND B      10
# SPADINA STATION             10
# YONGE UNIVERSITY LINE        9
# UNION STATION TO ST AN       9
# LINE 1                       9
# LINE 2 - BLOOR - DANFO       9
# BLOOR DANFORTH SUBWAY        9
# LINE 1 - YONGE-UNIVERS       8
# LINE 1 - YONGE - UNIVE       8
# VICTORIA PARK TO KENNE       8
# YONGE UNIVESITY LINE         7
# LINE 1 YUS                   6
# EGLINTON STATION TO CO       6
# GREENWOOD WYE                6
# KING STATION TO SPADIN       6
# UNION TO KING STATIONS       6
# YONGE- UNIVERSITY AND        6
# KENNEDY TO VICTORIA PA       5
# WILSON CARHOUSE              5
# UNION TO ST ANDREW STA       5
# YONGE STATION                5
# MCCOWAN YARD                 5
# YONGE / UNIVERSITY LIN       5
# ST GEORGE STATION            5
# BLOOR DANFORTH LINE 2        4
# YONGE-UNIVERSITY LINE        4
# BAY LOWER                    4
# KENNEDY STATION              4
# KEELE STATION - KIPLIN       4
# UNION STATION TOWARDS        4
# YORK MILLS TO ST CLAIR       4
# GREENWOOD PORTAL             4
# YONGE-UNIVERSITY SUBWA       4
# ST CLAIR WEST TO KING        3
# SUBWAY CLOSURE: ST GEO       3
# FINCH WEST TO SHEPPARD       3
# CHRISTIE TO PAPE STATI       3
# QUEENS PARK STATION          3
# EA CLOSURE SHEPPARD WE       3
# DAVISVILLE BUILDUP           3
# LINE 1 - YONGE/UNIVERS       3
# SHEPPARD WEST TO ST CL       3
# GREENWOOD COMPLEX            3
# ST. CLAIR STATION TO S       3
# YONGE AND BLOOR              3
# GREENWOOD SHOPS              3
# TRACK LEVEL ACTIVITY         3
# GREENWOOD CAR HOUSE          3
# EGLINTON TO COLLEGE ST       3
# UNION TO ST ANDREW           3
# DAVISVILLE CARHOUSE          3
# SHEPPARD WEST TO FINCH       3
# DUNDAS STATION TO EGLI       2
# YONGE UNIVERSITY SPADI       2
# YONGE - UNIVERSITY AND       2
# EGLINTON TO UNION STAT       2
# EGLINTON TO LAWRENCE         2
# KIPLING TO ISLINGTON S       2
# EGLINTON TO YORK MILLS       2
# WILSON HOSTLER               2
# SINGLE LINE OPERATIONS       2
# DANFORTH DIVISION            2
# YONGE - UNIVERSITY LIN       2
# UNION STATION (TO KING       2
# WARDEN TO VICTORIA PAR       2
# CHRISTIE STATION TO CH       2
# DAVISVILLE TO EGLINTON       2
# WILSON SOUTH HOSTLER         2
# BROADVIEW AND ST GEORG       2
# KING TO UNION                2
# EGLINTON STATION TO YO       2
# UNION STATION TO FINCH       2
# LANSDOWNE TO ROYAL YOR       2
# YU- YONGE-UNIVERSITY S       2
# LINE 2 - BLOOR-DANFORT       2
# JANE TO OLD MILL             2
# KIPLING TO ISLINGTON         2
# LINE 1 YONGE UNIVERSIT       2
# UNION STATION - ST AND       2
# DAVISVILLE BUILD-UP          2
# SHEPPARD LINE                2
# UNION TO KING STATION        2
# SCARBOROUGH CTR STATIO       2
# GREENWOOD TRACK AND ST       2
# WILSON CAR HOUSE             2
# OSGOODE POCKET               2
# SHEPPARD TO ST. CLAIR        2
# UNION STATION TO ST. A       2
# CHRISTIE STATION TO PA       2
# SYSTEM WIDE                  2
# LINE 1 - YONGE-UNIVERI       1
# APPROACHING DUNDAS WES       1
# HIGH PARK TO KEELE STA       1
# DUPONT STATION TO SPAD       1
# WOODBINE STATION (LEAV       1
# YONGE-UNIVERISTY & BLO       1
# QUEENS' QUAY STATION         1
# S/E MUSEUM / TO SE SPA       1
# DUPONT TO SPADINA            1
# UNION STATION TOWARD K       1
# QUEEN QUAY STATION           1
# YOUNGE-UNIVERSITY-SPAD       1
# UNION STATION ( TOWARD       1
# WILSON YARD- WILSON GA       1
# UNION STATION TO ST A        1
# TEDDINGTON EE                1
# SHEPPARD-YONGE AND ST        1
# (APPROACHING) KENNEDY        1
# OSSINGTON CENTRE             1
# N/END SPADINA TO S/END       1
# FINCH TO WILSON              1
# SHEPPARD WEST - ST CLA       1
# LINE 1- YONGE UNIVERSI       1
# EA SHEPPARD WEST TO ST       1
# WARDEN STATION (LEAVIN       1
# JANE & RUNNYMEDE STATI       1
# GO PROTOCOL - UNION, D       1
# UNION TO KING                1
# MAIN STREET STAITON          1
# SUBWAY LINE 1 YONGE -        1
# LINE 1 - YONGE-UNIVER        1
# KENNDY STATION               1
# UNION TO FINCH               1
# FINCH TO EGLINTON            1
# KIPLING TO HIGH PARK S       1
# E/O WARDEN TO W/O VICT       1
# FINCH TO UNION               1
# ST GEORGE - LAWRENCE W       1
# VAUGHAN MC TO FINCH ST       1
# ST CLAIR WEST TO DUPON       1
# FINCH STN 39 BUS PLATF       1
# UNION                        1
# BETWEEN WARDEN STATION       1
# N/O DUPONT TO N/END ST       1
# KIPLING TO OLD MILL          1
# LOST ARTICLES OFFICE -       1
# MCBRIEN BUILDING             1
# UNION STATION - KING         1
# WILSON STATION APPROAC       1
# ALL STATIONS                 1
# FINCH TO QUEENS PARK S       1
# YU & BD LINES                1
# YONGE/UNIVERSITY/SPADI       1
# SUMMERHILL STATION TO        1
# SUBWAY CLOSURE EARLY A       1
# FINCH TO ST CLAIR WEST       1
# ISLINGTON TO KEELE           1
# TORONTO TRANIST COMMIS       1
# BLOOR DANFORTHLINE           1
# YONGE-UNIVERSITY             1
# DONLANDS TO GREENWOD Y       1
# ST CLAIR TO YORK MILLS       1
# YONGE-UNIVERSITY-SPADI       1
# EGLINTON TO DAVISVILLE       1
# WILSON HOSTLER 2             1
# CHRISTIE CENTRE TRACK        1
# KING COMMERCE                1
# FINCH TO MUSEUM              1
# SHEBOURNE STATION            1
# YONGE UNIVERSITY / BLO       1
# MAIN STATION                 1
# ST. CLAIR WEST - KING        1
# CHANGE OVERS                 1
# DAVISVILLE TO LAWRENCE       1
# KING TO ST CLAIR WEST        1
# SPADINA TO WILSON STAT       1
# KING TO ST CLAIR W           1
# DAVISVILLE YARD / TRAC       1
# WELBECK EE                   1
# LINE 1 YONGE - UNIVERS       1
# WILSON HOSTLER - 2           1
# WOODBINE STATION TO CO       1
# QUEENS QUAY ELEVATOR         1
# ASQUITH SUBSTATION           1
# LAWRENCE WEST CENTER T       1
# ST CLAIR - YORK MILLS        1
# E/O WARDEN TO W/O WARD       1
# LAWRENCE TO BLOOR STAT       1
# HOSTLER 2 WILSON YARD        1
# ST. GEORGE STATION           1
# LINE 2 BLOOR-DANFORTH        1
# COXWELL TO GREENWOOD Y       1
# BLOOR / DANFORTH LINE        1
# BROADVIEW TO SCARBOROU       1
# EGLINTON YARD                1
# QUEENS QUAY STATION          1
# QUEENS QUAY ELEAVATOR        1
# GREENWOOD SHOP               1
# ST CLAIR AND UNION STA       1
# COXWELL TO KENNEDY           1
# LINE 2 BLOOR / DANFORT       1
# EGLINTON TO ST CLAIR S       1
# ROYAL YORK AND ISLINGT       1
# DUFFERIN STATON              1
# WILFRED EEB                  1
# YONGE-UNIVERSITY & BLO       1
# EGLINTON BUS TERMINAL        1
# KENNEDY, DON MILLS, SC       1
# LAWRENCE - AUTO ENTRAN       1
# ISLINGTON AND JANE           1
# WILSON YARD - 26 TRACK       1
# GREENWOOD TO DONLANDS        1
# KIPLING TO ROYAL YORK        1
# ISLINGTON TO OLD MILL        1
# SHEPPARD TAIL                1
# SUBWAY CLOSURE: WOODBI       1
# SHEPPARD WEST - FINCH        1
# KILPING STATION TO JAN       1
# OSSINGTON STATON             1
# WARDEN TO KENNEDY            1
# OSGOODE TO COLLEGE STA       1
# BAY STATION TO PAPE ST       1
# COLLEGE AND OSGOODE ST       1
# WILFRED EMERGENCY EXIT       1
# UNION TO BLOOR               1
# HIGH PARK - KEELE STAT       1
# CHRSTIE TO PAPE STATIO       1
# OSSINGTON AND LANSDOWN       1
# SHEPPARD WYE                 1
# YORK MILLS STATION TO        1
# YORK MILLS AND EGLINTO       1
# UNION STATION (TO ST.A       1
# MARKDALE EMERGENCY EXI       1
# DUNDAS TO FINCH STATIO       1
# OSSINGTON TO CHESTER         1
# KIPLING STATION TO COX       1
# EGLINTON STATION (APPR       1
# UNION STATION (TOWARD        1
# VMC AND FINCH WEST STA       1
# BLOOR SATION                 1
# KIPLING STATION TO KEN       1
# VAUGHAN MC STATION TO        1
# OLD MILLS STATION            1
# YONGE AND SHEPPARD           1
# EGLINTON TO COLLEGE          1
# CHRISTIE STATION (LEAV       1
# YOUNG UNIVERSITY LINE        1
# UNION STATION (TOWARDS       1
# YORK MILLS STATION - C       1
# LESLIE STATION (APPROA       1
# ST GEORGE BD/YU STATIO       1
# EGLINTON TO UNION            1
# S/O TEDDINGTON TO S/O        1
# WILSON YARD HOSTLER #2       1
# CHANGE OVERS LINE TWO        1
# HIGHWAY 407 STATION TO       1
# ST GEORGE TO PAPE            1
# SUBWAY CLOSURE: LAWREN       1
# LINE 1 SUBWAY CLOSURE        1
# FINCH WEST CENTER TRAC       1
# KIPLING STATION TO JAN       1
# OSSINGTON TO PAPE            1
# DOWNVIEW PARK STN - UN       1
# UNION STATION - HUB          1
# DUNDAS STATION W/S           1
# KIPLING TO UNION STATI       1
# SUBWAY CLOSURE: WEEKEN       1
# EGLINTON STATION (SOUT       1
# UNION AND DOWNSVIEW          1
# GO PROTOCOL - DANFORTH       1
# EARLY CLOSURE KING TO        1
# SPADINA TO KING              1
# SUBWAY CLOSURE: WARDEN       1
# SUBWAY CLOSURE BLOOR-D       1
# MILL STREET EMERGENCY        1
# UNION STATION--ST ANDR       1
# EGLINTON TO FINCH            1
# NORTH YORK CTR TO ST A       1
# DUFFERIN TO KIPLING          1
# UNION STATION HUB            1
# KING TO SPADINA              1
# DUNDAS TO FINCH              1
# BATHUST TO PAPE STATIO       1
# UNION CENTRE TRACK           1
# LEONA EE                     1
# UNION TO FINCH STATION       1
# KING STATION TO ST. CL       1
# YONGE UNIVERSITY SUBWA       1
# ST GEORGE AND WOODBINE       1
# SCARBOROUGH CENTRE STA       1
# SHEPPARD TO ST CLAIR S       1
# TORONTO TRANSIT CONTRO       1
# ST GEORGE TO BROADVIEW       1
# GREENWOOD SHOPS TRACK        1
# BLOOR STATION - YONGE        1
# ST. CLAIR AND SHEPPARD       1
# DUPONT TO ST CLAIR WES       1
# WEEKEND CLOSURE SHEPPA       1
# OLD MILL STATION TO JA       1
# YONGE BD STATION TO CO       1
# KENNEDY TO COXWELL           1
# DAVISVILLE STATION - B       1
# YU-ST CLAIR STATION TO       1
# GREENWOOD TRACK & STRU       1
# LESLIE STATION (ENTERI       1
# DAVISVILLE CAR HOUSE         1
# UNION STATION BROOKFIE       1
# 1900 YONGE ST- MCBRIEN       1
# COLLEGE TO ST.CLAIR ST       1
# YONGE BD STATION (ON R       1
# SHEPPARD TO YORK MILLS       1
# COLLEGE TO ST CLAIR          1
# MCDONALD CARTIER EMERG       1
# LINE 1: YONGE-UNIVERSI       1
# EGLINTON STN                 1
# ST. CLAIR TO COLLEGE S       1
# ST. ANDREW STATION           1
# ST GEOGE STATION             1
# 2233 SHEPPARD WEST           1
# SPADINA YU STATION           1
# YONGE UNIVERSITY             1
# UNION STATION - NB TO        1
# VARIOUS LOCATION             1
# MARKDALE EEB                 1
# EGLINTON TO UNION STA        1
# ROYAL YORK STATION(APP       1
# WILFRED EE                   1
# ISLINGTON TO KIPLING         1
# WEEKEND CLOSURE - WOOD       1
# VMC - ST CLAIR               1
# EARLY SUBWAY CLOSURE:        1
# SHEPPARD YONGE STATION       1
# ST GEORGE TO WOODBINE        1
# BUCHAN ESB                   1
# 1900 YONGE MCBRIEN BLD       1
# LAWRENCE TO EGLINTON         1
# VICTORIA PARK STATION-       1
# HIGH PARK AND LANSDOWN       1
# FINCH WEST TO VMC STAT       1
# YONGE STATION TO CHEST       1
# EGLINTON TO SHEPPARD-Y       1
# SHEPPARD TO EGLINTON S       1
# WISLON STATION               1
# MULTIPLE STATIONS            1
# DUPONT STATION TO EGLI       1
# GREENWOOD STATION CARH       1
# LEAVING ISLINGTON            1
# QUEENS QUAY (UNION)          1
# ST CLAIR TO DAVISVILLE       1
# DAVISVILLE STATION TO        1
# UNION - KING                 1
# RUSSEL HILL EE - INTRU       1
# EGLINTON STAION              1
# ISLINGTON SUBSTATION         1
# WILSON TRAINING CENTER       1
# BROADVIEW CENTRE TRACK       1
# 111 SPADINA ROAD             1
# HIGH PARK TO KEELE           1
# Name: count, dtype: int64

# %%
# Official TTC station names (Line 1 to 4)
official_station_names = {
    "BLOOR-YONGE STATION", "KENNEDY STATION", "FINCH STATION", "KIPLING STATION", "DUNDAS STATION",
    "SPADINA STATION", "EGLINTON STATION", "VAUGHAN MC STATION", "UNION STATION", "COLLEGE STATION",
    "VICTORIA PARK STATION", "WELLESLEY STATION", "ST GEORGE STATION", "WILSON STATION", "WARDEN STATION",
    "ST CLAIR STATION", "DAVISVILLE STATION", "KEELE STATION", "MAIN STREET STATION", "COXWELL STATION",
    "GREENWOOD STATION", "QUEEN STATION", "BROADVIEW STATION", "SHEPPARD STATION", "SHERBOURNE STATION",
    "KING STATION", "ST CLAIR WEST STATION", "DUNDAS WEST STATION", "BATHURST STATION", "SHEPPARD WEST STATION",
    "YORK MILLS STATION", "ISLINGTON STATION", "LAWRENCE STATION", "DUFFERIN STATION", "SHEPPARD-YONGE STATION",
    "WOODBINE STATION", "OSSINGTON STATION", "PAPE STATION", "ROSEDALE STATION", "EGLINTON WEST STATION",
    "DONLANDS STATION", "QUEENS PARK STATION", "DUPONT STATION", "LAWRENCE WEST STATION", "DON MILLS STATION",
    "ROYAL YORK STATION", "CHRISTIE STATION", "SUMMERHILL STATION", "NORTH YORK CENTRE STATION", "YORKDALE STATION",
    "JANE STATION", "BAY STATION", "OLD MILL STATION", "OSGOODE STATION", "FINCH WEST STATION",
    "ST ANDREW STATION", "ST PATRICK STATION", "MUSEUM STATION", "CASTLE FRANK STATION", "RUNNYMEDE STATION",
    "HIGHWAY 407 STATION", "LANSDOWNE STATION", "HIGH PARK STATION", "CHESTER STATION", "GLENCAIRN STATION",
    "LESLIE STATION", "DOWNSVIEW PARK STATION", "BAYVIEW STATION", "YORK UNIVERSITY STATION",
    "BESSARION STATION", "PIONEER VILLAGE STATION", "SCARBOROUGH CENTRE STATION", "MCCOWAN STATION"
}

# %%
station_corrections = {
    # Misspelled or partial station names
    "KENNDY STATION": "KENNEDY STATION",
    "KENNEDY BD STATION": "KENNEDY STATION",
    "WISLON STATION": "WILSON STATION",
    "OSSINGTON STATON": "OSSINGTON STATION",
    "BLOOR STATION": "BLOOR-YONGE STATION",
    "BLOOR SATION": "BLOOR-YONGE STATION",
    "DUFFERIN STATON": "DUFFERIN STATION",
    "MAIN STREET STAITON": "MAIN STREET STATION",
    "ST GEOGE STATION": "ST GEORGE STATION",
    "ST. GEORGE STATION": "ST GEORGE STATION",
    "EGLINTON STAION": "EGLINTON STATION",
    "EGLINTON STN": "EGLINTON STATION",
    "QUEEN'S PARK STATION": "QUEENS PARK STATION",
    "YONGE UNIVESITY LINE": "YONGE UNIVERSITY LINE",
    "YOUNG UNIVERSITY LINE": "YONGE UNIVERSITY LINE",
    "YONGE - UNIVERSITY LIN": "YONGE UNIVERSITY LINE",
    "YONGE-UNIVERSITY-SUPADI": "YONGE UNIVERSITY LINE",
    
    # Bloor-Yonge station variants
    "YONGE-UNIVERISTY & BLO": "BLOOR-YONGE STATION",
    "YONGE/UNIVERSITY AND B": "BLOOR-YONGE STATION",
    "YONGE UNIVERSITY AND B": "BLOOR-YONGE STATION",
    "YONGE BD STATION": "BLOOR-YONGE STATION",
    "YONGE BD STATION TO CO": "BLOOR-YONGE STATION",
    "YONGE - UNIVERSITY AND": "BLOOR-YONGE STATION",
    "YONGE STATION": "BLOOR-YONGE STATION",
    "YONGE / UNIVERSITY LIN": "BLOOR-YONGE STATION",
    "YONGE-UNIVERSITY SUBWA": "BLOOR-YONGE STATION",
    "YONGE AND BLOOR": "BLOOR-YONGE STATION",
    "YONGE-UNIVERSITY AND B": "BLOOR-YONGE STATION",
    "YU- YONGE-UNIVERSITY S": "BLOOR-YONGE STATION",
    "YONGE UNIVERSITY / BLO": "BLOOR-YONGE STATION",
    "YONGE UNIVERSITY": "BLOOR-YONGE STATION",
    "YONGE-UNIVERSITY": "BLOOR-YONGE STATION",
    "YONGE-UNIVERSITY & BLO": "BLOOR-YONGE STATION",
    "YONGE UNIVERSITY SUBWA": "BLOOR-YONGE STATION",
    "BLOOR STATION - YONGE": "BLOOR-YONGE STATION",

    # Spadina station variants
    "SPADINA YU STATION": "SPADINA STATION",
    "SPADINA YUS STATION": "SPADINA STATION",
    "SPADINA BD STATION": "SPADINA STATION",
    "YONGE UNIVERSITY SPADI": "SPADINA STATION",
    "YONGE-UNIVERSITY-SPADI": "SPADINA STATION",
    "YONGE/UNIVERSITY/SPADI": "SPADINA STATION",
    "YOUNGE-UNIVERSITY-SPAD": "SPADINA STATION",

    # Other station variants
    "SHEBOURNE STATION": "SHERBOURNE STATION",
    "YORK UNIVERSITY STATIO": "YORK UNIVERSITY STATION",
    "OLD MILLS STATION": "OLD MILL STATION",
    "ST. ANDREW STATION": "ST ANDREW STATION",
    "ST. CLAIR WEST - KING": "ST CLAIR WEST STATION",
    "ST CLAIR WEST TO DUPON": "ST CLAIR WEST STATION",
    "ST. CLAIR TO COLLEGE S": "ST CLAIR STATION",
    "ST. CLAIR AND SHEPPARD": "ST CLAIR STATION",
    "YORK MILLS STATION - C": "YORK MILLS STATION",
    "FINCH STN 39 BUS PLATF": "FINCH STATION",
    "ST GEORGE BD/YU STATIO": "ST GEORGE STATION",
    "ST GEORGE YUS STATION": "ST GEORGE STATION",
    "ST GEORGE BD STATION": "ST GEORGE STATION",
    "ST GEORGE - LAWRENCE W": "ST GEORGE STATION",
    "SHEPPARD YONGE STATION": "SHEPPARD-YONGE STATION",
    "SHEPPARD-YONGE AND ST": "SHEPPARD-YONGE STATION",
    "SCARBOROUGH CTR STATIO": "SCARBOROUGH CENTRE STATION",
    "SCARBOROUGH CENTRE STA": "SCARBOROUGH CENTRE STATION",
    "UNION STATION--ST ANDR": "UNION STATION",
    "UNION STATION - NB TO": "UNION STATION",
    "UNION STATION (TOWARD": "UNION STATION",
    "UNION STATION - KING": "UNION STATION",
    "UNION - KING": "UNION STATION",
    "UNION STATION BROOKFIE": "UNION STATION",
    "UNION STATION TO KING": "UNION STATION",
    "UNION STATION TO ST AN": "UNION STATION",
    "UNION STATION TO ST. A": "UNION STATION",
    "UNION": "UNION STATION",
    
    # Yard & depot locations treated as station
    "DAVISVILLE YARD": "DAVISVILLE STATION",
    "DAVISVILLE BUILD UP": "DAVISVILLE STATION",
    "GREENWOOD YARD": "GREENWOOD STATION",
    "WILSON YARD": "WILSON STATION",
    "KEELE YARD": "KEELE STATION",

    # Truncated or miswritten entries
    "ROYAL YORK STATION(APP": "ROYAL YORK STATION",
    "LESLIE STATION (APPROA": "LESLIE STATION",
    "LESLIE STATION (ENTERI": "LESLIE STATION",
    "CHRISTIE STATION (LEAV": "CHRISTIE STATION",
    "COLLEGE AND OSGOODE ST": "COLLEGE STATION",
    "OSSINGTON AND LANSDOWN": "OSSINGTON STATION",
    "OSSINGTON CENTRE": "OSSINGTON STATION",
    "WOODBINE STATION (LEAV": "WOODBINE STATION",
    "SHEPPARD TAIL": "SHEPPARD STATION",

    # Generic routing or non-station entries
    "LINE 1": "OTHER",
    "LINE 2 BLOOR DANFORTH": "OTHER",
    "YONGE UNIVERSITY LINE": "OTHER",
    "BLOOR DANFORTH LINE": "OTHER",
}

# %%
# STEP 3: Clean and correct station names
def clean_station_name(name):
    name = str(name).upper().strip()
    name = station_corrections.get(name, name)
    return name if name in official_station_names else "OTHER"

# Apply cleaning
df["Station_Cleaned"] = df["Station"].apply(clean_station_name)

# %%
pd.set_option('display.max_rows', None)
df['Station_Cleaned'].value_counts()
# Out:
# Station_Cleaned
# BLOOR-YONGE STATION           2095
# OTHER                          991
# KENNEDY STATION                965
# FINCH STATION                  897
# KIPLING STATION                894
# DUNDAS STATION                 829
# ST GEORGE STATION              802
# SPADINA STATION                745
# EGLINTON STATION               676
# UNION STATION                  616
# VAUGHAN MC STATION             606
# COLLEGE STATION                516
# VICTORIA PARK STATION          497
# DAVISVILLE STATION             471
# WILSON STATION                 464
# WELLESLEY STATION              456
# WARDEN STATION                 439
# KEELE STATION                  417
# ST CLAIR STATION               408
# COXWELL STATION                384
# MAIN STREET STATION            382
# QUEEN STATION                  371
# BROADVIEW STATION              367
# SHEPPARD STATION               365
# SHERBOURNE STATION             358
# KING STATION                   352
# ST CLAIR WEST STATION          349
# DUNDAS WEST STATION            348
# BATHURST STATION               326
# SHEPPARD WEST STATION          324
# YORK MILLS STATION             317
# ISLINGTON STATION              314
# LAWRENCE STATION               297
# DUFFERIN STATION               294
# SHEPPARD-YONGE STATION         287
# WOODBINE STATION               284
# OSSINGTON STATION              278
# PAPE STATION                   272
# ROSEDALE STATION               266
# EGLINTON WEST STATION          255
# DONLANDS STATION               250
# DUPONT STATION                 244
# QUEENS PARK STATION            244
# GREENWOOD STATION              242
# LAWRENCE WEST STATION          240
# DON MILLS STATION              239
# ROYAL YORK STATION             234
# CHRISTIE STATION               233
# SUMMERHILL STATION             230
# YORKDALE STATION               224
# JANE STATION                   222
# BAY STATION                    219
# OLD MILL STATION               218
# OSGOODE STATION                216
# FINCH WEST STATION             201
# ST ANDREW STATION              200
# ST PATRICK STATION             196
# MUSEUM STATION                 188
# CASTLE FRANK STATION           185
# RUNNYMEDE STATION              184
# HIGHWAY 407 STATION            170
# LANSDOWNE STATION              166
# HIGH PARK STATION              162
# CHESTER STATION                159
# LESLIE STATION                 138
# GLENCAIRN STATION              138
# DOWNSVIEW PARK STATION         123
# BAYVIEW STATION                121
# YORK UNIVERSITY STATION        104
# BESSARION STATION               67
# SCARBOROUGH CENTRE STATION       3
# Name: count, dtype: int64

# %% [markdown]
# # Cleaning 'Code' column data

# %%
# Temporarily expand display limits
pd.set_option('display.max_rows', None)

print(df['Code'].value_counts())
# Out:
# Code
# SUDP     3419
# MUIS     2680
# SUO      2506
# MUPAA    1729
# MUIRS    1489
# PUOPO    1461
# MUO      1217
# PUMEL     829
# MUIR      808
# MUNCA     804
# SUUT      722
# SUAP      582
# MUSC      552
# TUSC      510
# MUI       452
# MUSAN     451
# TUO       360
# PUMST     354
# SUG       352
# EUSC      282
# MUATC     267
# MUDD      232
# EUDO      213
# SUAE      212
# TUMVS     196
# MUTO      171
# PUMO      152
# MUIE      148
# TUNOA     140
# PUSAC     138
# TUNCA     129
# PUTWZ     126
# MUD       118
# EUNT      114
# PUTO      103
# TUNIP     101
# PUSTS      90
# SUEAS      86
# PUTR       85
# SUSA       84
# SUROB      80
# TUCC       74
# PUSTC      67
# MUPLB      67
# SUPOL      66
# EUBK       59
# EUCD       57
# PUSI       56
# TUS        55
# TUOS       52
# PUSRA      50
# MUGD       49
# PUSSW      49
# EUVE       46
# EUYRD      45
# TUATC      45
# EUO        45
# PUSNT      42
# TUSUP      41
# PUSO       41
# PUTOE      38
# MUWEA      37
# MUWR       36
# MUPR1      32
# EUME       31
# EUBO       30
# MUNOA      29
# PUTDN      29
# PUSCR      28
# EUPI       28
# EUAC       26
# MUPLC      25
# MUCL       25
# EUVA       23
# MUTD       22
# PUEO       21
# TUOPO      19
# EUOE       19
# PUSWZ      16
# EUOPO      15
# PUTD       15
# EUATC      15
# PUCSC      14
# PUTIJ      13
# EUTR       12
# EUNEA      12
# PUCSS      12
# TUSET      10
# MUFS        9
# TUKEY       9
# EUCO        9
# TUST        9
# EUCA        9
# SUBT        8
# EUECD       7
# PUTTC       6
# EUTRD       6
# PUATC       6
# PUSIS       6
# EUTL        6
# SUSP        6
# PUSCA       5
# EUAL        5
# MUPF        5
# PUTSM       4
# PUTS        4
# PUTIS       4
# EULT        3
# EULV        3
# PUTSC       3
# PUEWZ       2
# MUPLA       2
# PUSTP       2
# MUEC        2
# PUSZC       2
# PUEME       1
# EUTM        1
# XXXXX       1
# TUML        1
# TUDOE       1
# PUSIO       1
# PUTCD       1
# EUHV        1
# MUESA       1
# PUTTP       1
# Name: count, dtype: int64

# %%
df = df[df['Code'] != 'XXXXX']

# %%
code_freq = df['Code'].value_counts()
df['Code_Freq'] = df['Code'].map(code_freq)

# %%
# Save to a CSV file
df.to_csv("Transformed_data.csv", index=False)
